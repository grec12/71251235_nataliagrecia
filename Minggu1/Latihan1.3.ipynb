# %%
#definisi variabel awal
modal_awal = 200000000
target_uang = 400000000
bunga_tahunan = 0.1

bunga_pertahun = bunga_tahunan * modal_awal
waktu = target_uang/ bunga_pertahun

print(f"lama waktu yang dibutuhkan {waktu} tahun")
# Out:
# lama waktu yang dibutuhkan 20.0 tahun
